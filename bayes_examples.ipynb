# %% [markdown]
# All the terms used in the Bayesian interpretation of a pregnancy test:
#
# | Term                     | Definition                                                                                 |
# |--------------------------|--------------------------------------------------------------------------------------------|
# | $P(P)$                   | Prior probability of being pregnant                                                        |
# | $P(\neg P)$              | Prior probability of not being pregnant                                                    |
# | $P(T \mid P)$            | Probability of a positive test result given pregnancy (sensitivity)                        |
# | $P(T \mid \neg P)$       | Probability of a positive test result given not pregnant (false positive rate)             |
# | $P(\neg T \mid P)$       | Probability of a negative test result given pregnancy (false negative rate)                |
# | $P(\neg T \mid \neg P)$  | Probability of a negative test result given not pregnant (specificity)                     |
# | $P(P \mid T)$            | Posterior probability of being pregnant given a positive test result                       |
# | $P(T)$                   | Total probability of a positive test result                                                |
#
# These terms help us understand how the probabilities are updated using Bayes' theorem. If you have any more questions or need further clarification, feel free to ask!
# A table defining the terms used in the Bayesian interpretation of a pregnancy test, focusing on their meanings in the context of diagnostic testing:
#
# | Term               | Definition                                                                                 |
# |--------------------|--------------------------------------------------------------------------------------------|
# | Sensitivity        | The probability that the test correctly identifies a positive result when the condition (pregnancy) is present. Mathematically, $P(T \mid P)$.
# | Specificity        | The probability that the test correctly identifies a negative result when the condition (pregnancy) is not present. Mathematically, $P(\neg T \mid \neg P)$.
# | False Positive Rate| The probability that the test incorrectly identifies a positive result when the condition (pregnancy) is not present. It is equal to $1 - \text{Specificity}$. Mathematically, $P(T \mid \neg P)$.
# | False Negative Rate| The probability that the test incorrectly identifies a negative result when the condition (pregnancy) is present. It is equal to $1 - \text{Sensitivity}$. Mathematically, $P(\neg T \mid P)$.
# | Prior Probability   | The initial probability of the condition (pregnancy) before considering the test result. Mathematically, $P(P)$.
# | Posterior Probability| The updated probability of the condition (pregnancy) after considering the test result. Mathematically, $P(P \mid T)$.
# | Total Probability   | The overall probability of the test returning a positive result, considering both true positives and false positives. Mathematically, $P(T)$.
#
# These definitions should help clarify the terms used in the Bayesian interpretation. If you have any more questions or need further clarification, feel free to ask!

# %% [markdown]
# **Bayesian Interpretation of a Pregnancy Test**
#
# Let's consider a woman who suspects she might be pregnant. She takes a home pregnancy test, which results in a positive outcome. We'll assume the test has a sensitivity of 90% and a specificity of 95%.
#
# **Notation:**
#
# * **P(Pregnant):** Prior probability of being pregnant.
# * **P(Test+|Pregnant):** Probability of a positive test result given pregnancy (sensitivity).
# * **P(Test-|Not Pregnant):** Probability of a negative test result given not pregnant (specificity).
# * **P(Pregnant|Test+):** Posterior probability of being pregnant given a positive test result.
#
# **Bayes' Theorem:**
#
# $$P(Pregnant|Test+) = \frac{P(Test+|Pregnant) * P(Pregnant)}{P(Test+)}$$
#
# **Calculating P(Test+):**
#
# $$P(Test+) = P(Test+|Pregnant) * P(Pregnant) + P(Test+|Not Pregnant) * P(Not Pregnant)$$
#
# **Example:**
#
# Suppose the woman's prior belief of being pregnant is 30% (P(Pregnant) = 0.3).
#
# * **Calculating P(Test+):**
#   $$P(Test+) = 0.9 * 0.3 + 0.05 * 0.7 = 0.32$$
#
# * **Calculating Posterior Probability:**
#   $$P(Pregnant|Test+) = \frac{0.9 * 0.3}{0.32} ≈ 0.84$$
#
# **Interpretation:**
#
# After the positive test result, the woman's belief in being pregnant increases from 30% to approximately 84%.
#
# **Note:**
#
# * The prior probability plays a crucial role in the final posterior probability.
# * A more accurate test (higher sensitivity and specificity) will lead to a more reliable posterior probability.
# * Real-world scenarios may involve additional factors and uncertainties, but the Bayesian framework provides a robust approach to updating beliefs based on new evidence.
#
# When you render this markdown text on a platform that supports LaTeX, such as GitHub, GitLab, or a Jupyter Notebook, the LaTeX equations will be displayed correctly.

# %% [markdown]
# To understand the Bayesian interpretation of a pregnancy test, we can use Bayes' theorem, which relates the conditional and marginal probabilities of random events.
#
# Let:
#
# ( A ): the event that a woman is pregnant.
# ( B ): the event that the pregnancy test is positive.
# We can express Bayes' theorem as follows:
#
# $$ P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} $$
#
# Components of the Formula
# ( P(A|B) ): The probability that a woman is pregnant given that the test result is positive (posterior probability).
#
# ( P(B|A) ): The probability of a positive test result given that the woman is pregnant (sensitivity of the test).
#
# ( P(A) ): The prior probability that a woman is pregnant before taking the test.
#
# ( P(B) ): The total probability of a positive test result, which can be calculated using the law of total probability:
#
# $$ P(B) = P(B|A) \cdot P(A) + P(B|\neg A) \cdot P(\neg A) $$
#
# where ( P(B|\neg A) ) is the probability of a positive test result given that the woman is not pregnant (false positive rate), and ( P(\neg A) ) is the probability that a woman is not pregnant.
#
# Example Calculation
# Assuming:
#
# Sensitivity of the test ( P(B|A) = 0.93 ) (93% of pregnant women test positive).
# False positive rate ( P(B|\neg A) = 0.05 ) (5% of non-pregnant women test positive).
# Prior probability of being pregnant ( P(A) = 0.10 ) (10% of women taking the test are actually pregnant).
# We can calculate ( P(B) ):
#
# $$ P(B) = P(B|A) \cdot P(A) + P(B|\neg A) \cdot P(\neg A) $$
#
# Substituting the values:
#
# $$ P(B) = (0.93 \cdot 0.10) + (0.05 \cdot 0.90) = 0.093 + 0.045 = 0.138 $$
#
# Now, we can find ( P(A|B) ):
#
# $$ P(A|B) = \frac{P(B|A) \cdot P(A)}{P(B)} = \frac{0.93 \cdot 0.10}{0.138} \approx 0.673 $$
#
# Conclusion
# The Bayesian interpretation of a pregnancy test shows that even with a positive result, the probability that a woman is actually pregnant is approximately 67%. This highlights the importance of considering both the sensitivity of the test and the prior probability of pregnancy when interpreting test results.

# %% [markdown]
# ### Definitions
# - **$P(P)$**: Prior probability of being pregnant.
# - **$P(\neg P)$**: Prior probability of not being pregnant.
# - **$P(T \mid P)$**: Probability of a positive test result given pregnancy (sensitivity).
# - **$P(T \mid \neg P)$**: Probability of a positive test result given not pregnant (false positive rate).
# - **$P(\neg T \mid P)$**: Probability of a negative test result given pregnancy (false negative rate).
# - **$P(\neg T \mid \neg P)$**: Probability of a negative test result given not pregnant (specificity).
#
# ### Bayes' Theorem
# Bayes' theorem allows us to update the probability of being pregnant given a positive test result ($P(P \mid T)$):
#
# $$
# P(P \mid T) = \frac{P(T \mid P) \cdot P(P)}{P(T)}
# $$
#
# Where $P(T)$ is the total probability of a positive test result:
#
# $$
# P(T) = P(T \mid P) \cdot P(P) + P(T \mid \neg P) \cdot P(\neg P)
# $$
#
# ### Practical Example
# Let's assume:
# - Prior probability of being pregnant ($P(P)$) is 0.1.
# - Sensitivity of the test ($P(T \mid P)$) is 0.99.
# - False positive rate ($P(T \mid \neg P)$) is 0.05.
#
# First, calculate $P(T)$:
#
# $$
# P(T) = (0.99 \cdot 0.1) + (0.05 \cdot 0.9) = 0.099 + 0.045 = 0.144
# $$
#
# Next, apply Bayes' theorem:
#
# $$
# P(P \mid T) = \frac{0.99 \cdot 0.1}{0.144} = \frac{0.099}{0.144} \approx 0.6875
# $$
#
# So, given a positive test result, the updated probability of being pregnant is approximately 68.75%.
#
# This Bayesian approach helps in understanding how test results update our beliefs about the probability of being pregnant, considering both prior knowledge and the characteristics of the test.

# %% [markdown]
# Apply Bayesian reasoning to understand the probability that your friend will wear a raincoat given a weather forecast that predicts a percentage chance of rain.
#
# ### Definitions
# - **$P(R)$**: Prior probability of your friend wearing a raincoat regardless of the forecast.
# - **$P(F)$**: Probability of the forecast predicting rain.
# - **$P(F \mid R)$**: Probability of the forecast predicting rain given your friend wears a raincoat.
# - **$P(F \mid \neg R)$**: Probability of the forecast predicting rain given your friend does not wear a raincoat.
# - **$P(R \mid F)$**: Posterior probability of your friend wearing a raincoat given the forecast predicts rain.
#
# ### Bayes' Theorem
# Bayes' theorem helps update the probability of your friend wearing a raincoat given the forecast:
#
# $$
# P(R \mid F) = \frac{P(F \mid R) \cdot P(R)}{P(F)}
# $$
#
# Where $P(F)$ is the total probability of the forecast predicting rain:
#
# $$
# P(F) = P(F \mid R) \cdot P(R) + P(F \mid \neg R) \cdot P(\neg R)
# $$
#
# ### Practical Example
# Assume:
# - **$P(R)$**: Your friend wears a raincoat 30% of the time regardless of the forecast ($P(R) = 0.3$).
# - **$P(F \mid R)$**: If your friend wears a raincoat, there's an 80% chance the forecast predicts rain ($P(F \mid R) = 0.8$).
# - **$P(F \mid \neg R)$**: If your friend does not wear a raincoat, there's a 10% chance the forecast predicts rain ($P(F \mid \neg R) = 0.1$).
#
# First, calculate $P(F)$:
#
# $$
# P(F) = (0.8 \cdot 0.3) + (0.1 \cdot 0.7) = 0.24 + 0.07 = 0.31
# $$
#
# Next, apply Bayes' theorem:
#
# $$
# P(R \mid F) = \frac{0.8 \cdot 0.3}{0.31} = \frac{0.24}{0.31} \approx 0.7742
# $$
#
# So, given that the forecast predicts rain, the updated probability that your friend will wear a raincoat is approximately 77.42%.
#
# This Bayesian approach helps in understanding how the forecast affects your friend's decision to wear a raincoat, considering both prior knowledge and the forecast's accuracy. If you need more details or have further questions, feel free to ask!
#
# ----
# ----

# %% [markdown]
# Sure! Here are a few examples to illustrate how Bayes' theorem can be applied in different scenarios:
#
# **Medical Diagnosis**
# * Suppose a certain disease affects 1% of the population ($P(D) = 0.01$).
# * A test for this disease has a 99% sensitivity ($P(T \mid D) = 0.99$)
# * and a 5% false positive rate ($P(T \mid \neg D) = 0.05$).
# We want to find the probability that a person has the disease given a positive test result ($P(D \mid T)$).
#
# First, calculate $P(T)$:
#
# \begin{align*}
#     P(T) &= P(T \mid D) \cdot P(D) + P(T \mid \neg D) \cdot P(\neg D) \\
#     &= (0.99 \cdot 0.01) + (0.05 \cdot 0.99) \\
#     &= 0.0099 + 0.0495
#     \\ &= 0.0594
# \end{align*}
#
#
# Next, apply Bayes' theorem:
# \begin{align*}
#     P(D \mid T) &= \frac{P(T \mid D) \cdot P(D)}{P(T)} \\
#     &= \frac{0.99 \cdot 0.01}{0.0594} \\
#     & \approx 0.167
# \end{align*}
#
# So, given a positive test result, the probability that a person has the disease is approximately 16.7%.
#
# **Spam Email Detection**
# Let's say you have an email filter that classifies emails as spam based on certain keywords.
# * The probability that an email is spam ($P(S)$) is 20% ($P(S) = 0.2$).
# * The probability that an email contains certain keywords given it is spam ($P(K \mid S)$) is 90% ($P(K \mid S) = 0.9$).
# * The probability that an email contains the same keywords given it is not spam ($P(K \mid \neg S)$) is 10% ($P(K \mid \neg S) = 0.1$).
#
# We want to find the probability that an email is spam given it contains the keywords ($P(S \mid K)$).
#
# First, calculate $P(K)$:
# \begin{align*}
#     P(K) &= P(K \mid S) \cdot P(S) + P(K \mid \neg S) \cdot P(\neg S) \\
#     &= (0.9 \cdot 0.2) + (0.1 \cdot 0.8)  \\
#     &= 0.18 + 0.08 = 0.26
# \end{align*}
#
# Next, apply Bayes' theorem:
# \begin{align*}
#     P(S \mid K) &= \frac{P(K \mid S) \cdot P(S)}{P(K)} \\
#     &= \frac{0.9 \cdot 0.2}{0.26} \approx 0.692
# \end{align*}
#
# So, given that an email contains the keywords, the probability that it is spam is approximately 69.2%.
#
# **Quality Control in Manufacturing**
# * In a factory, 2% of products are defective ($P(D) = 0.02$).
# * The inspection process correctly identifies defective products 95% of the time ($P(T \mid D) = 0.95$)
# * and falsely identifies non-defective products as defective 1% of the time ($P(T \mid \neg D) = 0.01$).
#
# We want to find the probability that a product is defective given it failed the inspection ($P(D \mid T)$).
#
# First, calculate $P(T)$:
# \begin{align*}
#     P(T) &= P(T \mid D) \cdot P(D) + P(T \mid \neg D) \cdot P(\neg D)\\
#     &= (0.95 \cdot 0.02) + (0.01 \cdot 0.98) \\
#     &=  0.019 + 0.0098 = 0.0288
# \end{align*}
#
# Next, apply Bayes' theorem:
# \begin{align*}
#     P(D \mid T) &= \frac{P(T \mid D) \cdot P(D)}{P(T)}\\
#     &= \frac{0.95 \cdot 0.02}{0.0288} \approx 0.659
# \end{align*}
#
# So, given that a product failed the inspection, the probability that it is defective is approximately 65.9%.
#
# These examples demonstrate how Bayes' theorem can be used to update probabilities based on new evidence in various contexts.
